# %%
import pandas as pd 
import plotly.express as px

import plotly.io as pio

pio.renderers.default = "png"

# %%
df = px.data.gapminder().query("country=='Canada'")
fig = px.line(df, x="year", y="lifeExp", template = "plotly_dark", title='Life expectancy in Canada')
fig.show()

# %% [markdown]
# Render

# %%
print(1254)
# Out:
# 1254

# %%
123
# Out:
# 123

# %% [markdown]
# Yes this is chart
